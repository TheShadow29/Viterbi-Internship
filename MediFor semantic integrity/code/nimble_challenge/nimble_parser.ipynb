# %%
import csv

# %%
f = open('/arka_data/NC2016_Test0613/indexes/NC2016-manipulation-index_new.csv')
#reader = csv.reader(f,delimiter=',')
field_names = f.readline()
print field_names
all_data = f.readlines()
prin

#for row in reader:
    #print(row)
    #print '\n '.join(row)
    #print ', '.join(row)
# Out:
# TaskID,ProbeFileID,ProbeFileName,ProbeWidth,ProbeHeight
#
# ...

# %%
a1 = all_data[0].split(',')
a1[-1].split('\n')
# Out:
# ['3024', '']

# %%
import csv
#g = open('/arka_data/NC2016_Test0613/indexes/NC2016-manipulation-index_new.csv')
g = open('/arka_data/NC2016_Test0613/reference/manipulation/NC2016-manipulation-ref_new.csv')
reader = csv.reader(g,delimiter=',',quotechar = '|')
a = reader.next()
for row in reader:
    print row
# print reader.next()
#for row in reader:
 #   print ', '.join(row)
# Out:
# ['Manipulation', 'NC2016_0098', 'probe/NC2016_0098.jpg', '', '', '', '', 'N', 'none', '', '', 'N', 'N', 'N', 'Nimble-SCI', '', '', 'Y', '', '']
# ['Manipulation', 'NC2016_0136', 'probe/NC2016_0136.jpg', '', '', '', '', 'N', 'none', '', '', 'N', 'N', 'N', 'Nimble-SCI', '', '', 'Y', '', '']
# ['Manipulation', 'NC2016_0324', 'probe/NC2016_0324.jpg', '', '', '', '', 'N', 'none', '', '', 'N', 'N', 'N', 'Nimble-SCI', '', '', 'Y', '', '']
# ['Manipulation', 'NC2016_0820', 'probe/NC2016_0820.jpg', '', '', '', '', 'N', 'none', '', '', 'N', 'N', 'N', 'Nimble-SCI', '', '', 'Y', '', '']
# ['Manipulation', 'NC2016_1262', 'probe/NC2016_1262.jpg', '', '', '', '', 'N', 'none', '', '', 'N', 'N', 'N', 'Nimble-SCI', '', '', 'Y', '', '']
# ['Manipulation', 'NC2016_1956', 'probe/NC2016_1956.jpg', '', '', '', '', 'N', 'none', '', '', 'N', 'N', 'N', 'Nimble-SCI', '', '', 'Y', '', '']
# ...

# %%
import re
def convert(name):
    s1 = re.sub('(.)([A-Z][a-z]+)', r'\1_\2', name)
    return re.sub('([a-z0-9])([A-Z])', r'\1_\2', s1).lower()

# %%
print  a
for i,t in enumerate(a):
    print ('self.' + str(convert(t)) + ' = reference_data[' + str(i) + ']')
# Out:
# ['TaskID', 'ProbeFileID', 'ProbeFileName', 'ProbeMaskFileName', 'DonorFileID', 'DonorFileName', 'DonorMaskFileName', 'IsTarget', 'ProbePostProcessed', 'DonorPostProcessed', 'ManipulationQuality', 'IsManipulationTypeRemoval', 'IsManipulationTypeSplice', 'IsManipulationTypeCopyClone', 'Collection', 'BaseFileName', 'Lighting', 'IsControl', 'CorrespondingControlFileName', 'SemanticConsistency']
# self.task_id = reference_data[0]
# self.probe_file_id = reference_data[1]
# self.probe_file_name = reference_data[2]
# self.probe_mask_file_name = reference_data[3]
# self.donor_file_id = reference_data[4]
# self.donor_file_name = reference_data[5]
# self.donor_mask_file_name = reference_data[6]
# self.is_target = reference_data[7]
# self.probe_post_processed = reference_data[8]
# self.donor_post_processed = reference_data[9]
# self.manipulation_quality = reference_data[10]
# self.is_manipulation_type_removal = reference_data[11]
# self.is_manipulation_type_splice = reference_data[12]
# ...

# %%
class Complex:
    def __init__(self, real = 0,img = 0):
        self.r = real
        self.i = img
x = Complex()
print x.r, x.i
# Out:
# 0 0

# %%
f = open('/arka_data/NC2016_Test0613/reference/removal/NC2016-removal-ref_new.csv')
#reader = csv.reader(f,delimiter=',')
field_names = f.readline()
print field_names
all_data = f.readlines()
print all_data

#for row in reader:
    #print(row)
    #print '\n '.join(row)
    #print ', '.join(row)
# Out:
# TaskID,ProbeFileID,ProbeFileName,ProbeMaskFileName,DonorFileID,DonorFileName,DonorMaskFileName,IsTarget,ProbePostProcessed,DonorPostProcessed,ManipulationQuality,IsManipulationTypeRemoval,IsManipulationTypeSplice,IsManipulationTypeCopyClone,Collection,BaseFileName,Lighting,IsControl,CorrespondingControlFileName,SemanticConsistency
#
# ...

# %%
class Pizza(object):
    def __init__(self):
        self.toppings = []
    def __call__(self, topping):
        # when using '@instance_of_pizza' before a function def
        # the function gets passed onto 'topping'
        self.toppings.append(topping())
    def __repr__(self):
#         return str(self.toppings)
        return '0'
pizza = Pizza()

@pizza
def cheese():
    return 'cheese'
@pizza
def sauce():
    return 'sauce'

print pizza
# Out:
# 0

# %%
run parse_all_data.py

# %%
dir(man_nimble_ref)
# vars(man_nimble_ref.data[0])
print ([vars(k) for k in man_nimble_ref.data])
# for ref in man_nimble_ref.data:
#     print ref
# Out:
# [{'probe_file_id': 'NC2016_0098', 'is_target': 'N', 'is_manipulation_type_removal': 'N', 'donor_post_processed': '', 'probe_post_processed': 'none', 'task_id': 'Manipulation', 'manipulation_quality': '', 'donor_file_id': '', 'base_file_name': '', 'collection': 'Nimble-SCI', 'probe_mask_file_name': '', 'is_manipulation_type_copy_clone': 'N', 'probe_file_name': 'probe/NC2016_0098.jpg', 'donor_file_name': '', 'is_control': 'Y', 'corresponding_control_file_name': '', 'lighting': '', 'is_manipulation_type_splice': 'N', 'donor_mask_file_name': '', 'semantic_consistency': ''}, {'probe_file_id': 'NC2016_0136', 'is_target': 'N', 'is_manipulation_type_removal': 'N', 'donor_post_processed': '', 'probe_post_processed': 'none', 'task_id': 'Manipulation', 'manipulation_quality': '', 'donor_file_id': '', 'base_file_name': '', 'collection': 'Nimble-SCI', 'probe_mask_file_name': '', 'is_manipulation_type_copy_clone': 'N', 'probe_file_name': 'probe/NC2016_0136.jpg', 'donor_file_name': '', 'is_control'
# ...
